# %%
import pandas as pd

# %%
dd=pd.read_csv("bad_daraz_dataset.csv")
# for category,data in dd.groupby("category"):
#     print(category)
#     print(data)
# # electronics=dd.groupby("category").get_group("electronics")
# fashion=dd.groupby("category").get_group("Fashion")
# fashion

# for city,data in dd.groupby("city"):
#     print(city)

# dd.groupby("city").get_group("Janakpur")

# %%
# dd.groupby("category")["price"].agg(["mean","max","min"])
# dd.groupby("category")["price"].mean()

# %%
dd.groupby("category").agg({
    "price":["mean","max"],
    "rating":["mean","max"]
})
# Out:
#                     price             rating
#                      mean      max      mean  max
# category
# Accessories   5500.000000   5500.0  4.500000  4.5
# Electronics  26833.333333  75000.0  4.485714  4.8
# Fashion       3333.333333   5000.0  4.050000  4.2
# Furniture     2500.000000   2500.0  4.000000  4.0
# Home           800.000000    800.0  5.500000  5.5
