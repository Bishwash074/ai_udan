# %%
import pandas as pd;

# %%
data={
    "Name":["Ram","Hari","Sita","Bishwas"],
    "Age":[20,30,40,35],
    "Marks":[80,65,90,75]
}
df=pd.DataFrame(data)
df
# Out:
#       Name  Age  Marks
# 0      Ram   20     80
# 1     Hari   30     65
# 2     Sita   40     90
# 3  Bishwas   35     75

# %%
df.head()
df["Name"]
df["Marks"].mean()
df["Marks"].max()
df["Marks"].sort_values()
# Out:
# 1    65
# 3    75
# 0    80
# 2    90
# Name: Marks, dtype: int64
