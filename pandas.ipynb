# %%
import pandas as pd

# %%
result=pd.Series(["japan","usa","nepal"])
print(result)
# Out:
# 0    japan
# 1      usa
# 2    nepal
# dtype: object

# %%
number_series=pd.Series([10,20,30],index=["ek","dui","tin"])
print(number_series["dui"])
# Out:
# 20

# %%
student_data=pd.DataFrame({
    "name":["manish","biswas","nish"],
    "age":[24,23,22],
    "course":["ai_udan","mern","reactjs"]
        
})
print(student_data)
# Out:
#      name  age   course
# 0  manish   24  ai_udan
# 1  biswas   23     mern
# 2    nish   22  reactjs

# %%
student_data = pd.read_csv("dataset/data.csv", delimiter=";")
print(student_data)
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# ...

# %%
# nd=pd.read_csv("dataset/netflix_dataset.csv")
# print(nd.head(2)) top or first 5 rows return garxa
# print(nd.tail(2))   last 5 rows dinxa 
# print(nd.sample(3)) randomly 3 ta dinx
# print(nd.shape) dataset ma kati ota (rows,coloumn) dinxa
# print(nd.columns) dataset ma coloumn dinxa
# print(nd.dtypes) dataset ma vako column ko datatypes return garxa
# print(nd.info()) shape,column,dtypes all in one master method
# print(nd.describe())

# %%
nd=pd.read_json("dataset/students_data.json")

print(nd.head())
print(nd.tail(3))
print(nd.shape)
print(nd.columns)
print(nd.dtypes)
print(nd.info())
print(nd.describe())
# Out:
#    id           name  age  gender       phone                     email  \
# 0   1  Sabina Pandey   19    Male  9866879003  sabina.pandey1@gmail.com
# 1   2   Sujan Poudel   28    Male  9870676580   sujan.poudel2@gmail.com
# 2   3   Nabin Pandey   26    Male  9834006426   nabin.pandey3@gmail.com
# 3   4   Roshan Regmi   27  Female  9811229824   roshan.regmi4@gmail.com
# 4   5   Anisha Regmi   25    Male  9824458163   anisha.regmi5@gmail.com
#
#     location   district province                        courses_enrolled  \
# 0     Dharan    Sunsari    Koshi                           [NodeJS, C++]
# 1  Nepalgunj      Banke  Lumbini                               [Flutter]
# 2  Kathmandu  Kathmandu  Bagmati  [Django, Deep Learning, Python, React]
# 3     Dharan    Sunsari    Koshi         [Figma, Python, Flutter, Excel]
# 4    Chitwan    Chitwan  Bagmati                          [Data Science]
#
#    fees_paid  fees_due  attendance  marks         batch   join_date  passed  \
# ...

# %%
nd=pd.read_json("dataset/students_data.json")
nd["name"]
nd[["name","age"]]
# print(nd.loc[0])
# print(nd.iloc[-1])
# print(nd.iloc[4])
nd[nd["location"]=="Kathmandu"]
nd[nd["age"]>21]
nd[nd["gender"]=="Female"]
nd[nd["attendance"]>90]
nd[nd["marks"]>85]
nd[nd["courses_enrolled"].apply(lambda x: "Python" in x)]
# Out:
#       id             name  age  gender       phone  \
# 2      3     Nabin Pandey   26    Male  9834006426
# 3      4     Roshan Regmi   27  Female  9811229824
# 17    18     Sabina Dahal   19  Female  9888478039
# 19    20  Sabina Shrestha   20  Female  9851899869
# 22    23  Nabin Bhattarai   24    Male  9833072767
# ..   ...              ...  ...     ...         ...
# 468  469        Roshan KC   24  Female  9873162845
# 470  471     Asmita Joshi   26    Male  9806889815
# 473  474    Ritika Pandey   27    Male  9840557150
# 484  485   Alina Bhandari   26    Male  9801096657
# 490  491         Pooja KC   28  Female  9867136985
#
#                            email   location   district province  \
# 2        nabin.pandey3@gmail.com  Kathmandu  Kathmandu  Bagmati
# 3        roshan.regmi4@gmail.com     Dharan    Sunsari    Koshi
# 17      sabina.dahal18@gmail.com    Itahari    Sunsari    Koshi
# 19   sabina.shrestha20@gmail.com  Nepalgunj      Banke  Lumbini
# ...
